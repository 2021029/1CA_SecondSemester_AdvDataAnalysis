# %% [markdown]
# ## Sentiment Analysis about Climate Change from YouTube and Tweeter

# %% [markdown]
# #### GitHub link  - https://github.com/joycesimiao/1CA_SecondSemester_AdvDataAnalysis

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
from textblob import TextBlob
from wordcloud import WordCloud
import re
from unidecode import unidecode
from string import punctuation
import ipywidgets as widgets
from IPython.display import clear_output
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix

# Libraries to read tokens for Youtue text.
import googleapiclient.errors 
import googleapiclient.discovery

# %%
# Token for scrapping Youtube website 
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyA9pGHFEHGsjv80w4THTZ9xJwdCN0TM9_Y"

# %%
# Getting comments from video 1 - ClickView - What is Climate Change? Explore the Causes of Climate Change
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId='EuwMB1Dal-4',
    maxResults=1000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

commentYoutube = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

commentYoutube.head()
# Out:
#                    author          published_at            updated_at  \
# 0  Joy chardonnay Roberts  2023-10-07T23:40:01Z  2023-10-07T23:40:01Z
# 1       Salpi Vartivarian  2023-10-02T13:36:41Z  2023-10-02T13:38:53Z
# 2          Anthony Morris  2023-10-01T23:10:07Z  2023-10-01T23:10:07Z
# 3                     Rmg  2023-10-01T21:59:56Z  2023-10-01T21:59:56Z
# 4  NASA Cosmos Connection  2023-10-01T14:01:34Z  2023-10-01T14:01:34Z
#
#    like_count                                               text
# 0           0                         Don&#39;t believe the hype
# 1           0  I think there is a problem around <a href="htt...
# 2           0  What is climate change? It&#39;s an anti capit...
# 3           0  Climate change is World pieces of s*** I mean ...
# 4           0  <a href="https://www.youtube.com/watch?v=FT3La...

# %%
# Getting comments from video 2 - DW documentary - Climate change - Averting catastrophe | DW Documentary
request = youtube.commentThreads().list(
    part="snippet",
    videoId='pEt6-jA2UE4',
    maxResults=1000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

commentYoutube1 = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

commentYoutube1.tail()
# Out:
#             author          published_at            updated_at  like_count  \
# 95          gayrtz  2023-09-24T16:51:50Z  2023-09-24T16:51:50Z           1
# 96  Giorgio Cooper  2023-09-24T12:03:01Z  2023-09-24T12:03:01Z           1
# 97         Bournai  2023-09-24T12:02:34Z  2023-09-24T12:02:34Z           0
# 98    Captain Jack  2023-09-24T10:25:48Z  2023-09-24T10:25:48Z           0
# 99     John Thomas  2023-09-23T13:09:17Z  2023-09-23T13:09:17Z           5
#
#                                                  text
# 95  This is what happens when you don&#39;t listen...
# 96  How are u gonna « avert » mainly natural clima...
# 97  Telling the ever-hungry to stop eating will ne...
# 98  My 7th grade science teacher told the class, w...
# 99  It&#39;s wild that you can watch the permafros...

# %%
# Concating both files and changing Index
comment_Youtube = pd.concat([commentYoutube, commentYoutube1], ignore_index = True)
display(comment_Youtube)
# Out:
#                      author          published_at            updated_at  \
# 0    Joy chardonnay Roberts  2023-10-07T23:40:01Z  2023-10-07T23:40:01Z
# 1         Salpi Vartivarian  2023-10-02T13:36:41Z  2023-10-02T13:38:53Z
# 2            Anthony Morris  2023-10-01T23:10:07Z  2023-10-01T23:10:07Z
# 3                       Rmg  2023-10-01T21:59:56Z  2023-10-01T21:59:56Z
# 4    NASA Cosmos Connection  2023-10-01T14:01:34Z  2023-10-01T14:01:34Z
# ..                      ...                   ...                   ...
# 195                  gayrtz  2023-09-24T16:51:50Z  2023-09-24T16:51:50Z
# 196          Giorgio Cooper  2023-09-24T12:03:01Z  2023-09-24T12:03:01Z
# 197                 Bournai  2023-09-24T12:02:34Z  2023-09-24T12:02:34Z
# 198            Captain Jack  2023-09-24T10:25:48Z  2023-09-24T10:25:48Z
# 199             John Thomas  2023-09-23T13:09:17Z  2023-09-23T13:09:17Z
#
#      like_count                                               text
# 0             0                         Don&#39;t believe the hype
# 1             0  I think there is a problem around <a href="htt...
# 2             0  What is climate change? It&#39;s an anti capit...
# 3             0  Climate change is World pieces of s*** I mean ...
# 4             0  <a href="https://www.youtube.com/watch?v=FT3La...
# ..          ...                                                ...
# 195           1  This is what happens when you don&#39;t listen...
# 196           1  How are u gonna « avert » mainly natural clima...
# 197           0  Telling the ever-hungry to stop eating will ne...
# 198           0  My 7th grade science teacher told the class, w...
# 199           5  It&#39;s wild that you can watch the permafros...
#
# [200 rows x 5 columns]

# %%
print(comment_Youtube.shape)
# Out:
# (200, 5)

# %%
# Creating a CSV file. It is as commento to avoid errors.

#comment_Youtube.to_csv('commentsYoutube.csv')

# %%
# Loading the files
commentsYoutube = pd.read_csv("C:/Users/joyce/Downloads/commentsYoutube.csv")
twitter = pd.read_csv("C:/Users/joyce/Downloads/twitter_sentiment_data.csv")

# %%
# Creating text for the Tokenize
example = commentsYoutube['text'][:,]
print(example)
# Out:
# 0      Sea level has been suddenly rising? Sea levels...
# 1      I&#39;ve been searching for a good video for m...
# 2                                           Leave a mark
# 3      Very informative and the best video on the top...
# 4      Let&#39;s face it: Root cause is human breedin...
#                              ...
# 195    Yes, we know that C02 is a green house gas as ...
# 196    More climate fraud from rich billionaires, Mak...
# 197    the poor And rural family cause less carbon em...
# 198             Fun fact: the climate has always changed
# 199                                         Meine Arsch!
# Name: text, Length: 200, dtype: object

# %%
# Getting a row to tokenize - Selected the fisrt row to see the result
example2 = commentsYoutube['text'][0]
print(example2)
# Out:
# Sea level has been suddenly rising? Sea levels have been rising at the same rate for hundreds of years. It’s easy to find the statistics on NOAA’s website.

# %%
# Checking tokenize result
nltk.word_tokenize(example2)
# Out:
# ['Sea',
#  'level',
#  'has',
#  'been',
#  'suddenly',
#  'rising',
#  '?',
#  'Sea',
#  'levels',
#  'have',
#  'been',
#  'rising',
#  'at',
#  'the',
#  'same',
#  'rate',
#  'for',
#  'hundreds',
#  'of',
#  'years',
#  '.',
#  'It',
#  '’',
#  's',
#  'easy',
#  'to',
#  'find',
#  'the',
#  'statistics',
#  'on',
#  'NOAA',
#  '’',
#  's',
#  'website',
#  '.']

# %%
# Tokenizing to apply pos_tag
token_1 = nltk.word_tokenize(example2)

# %%
#pos_tag bring according the documentation what each abbreviation means. JJ is adjective, NN is a singular noun 
nltk.pos_tag(token_1)
# Out:
# [('Sea', 'NNP'),
#  ('level', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('suddenly', 'RB'),
#  ('rising', 'VBG'),
#  ('?', '.'),
#  ('Sea', 'NNP'),
#  ('levels', 'NNS'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('rising', 'VBG'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('rate', 'NN'),
#  ('for', 'IN'),
#  ('hundreds', 'NNS'),
#  ('of', 'IN'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('’', 'VBD'),
#  ('s', 'JJ'),
#  ('easy', 'JJ'),
#  ('to', 'TO'),
#  ('find', 'VB'),
#  ('the', 'DT'),
#  ('statistics', 'NNS'),
#  ('on', 'IN'),
#  ('NOAA', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('website', 'NN'),
#  ('.', '.')]

# %%
# Selecting 10 first rows
tagged = nltk.pos_tag(token_1)
tagged[:10]
# Out:
# [('Sea', 'NNP'),
#  ('level', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('suddenly', 'RB'),
#  ('rising', 'VBG'),
#  ('?', '.'),
#  ('Sea', 'NNP'),
#  ('levels', 'NNS'),
#  ('have', 'VBP')]

# %%
# Turning tags into trees
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   (GPE Sea/NNP)
#   level/NN
#   has/VBZ
#   been/VBN
#   suddenly/RB
#   rising/VBG
#   ?/.
#   Sea/NNP
#   levels/NNS
#   have/VBP
#   been/VBN
#   rising/VBG
#   at/IN
#   the/DT
#   same/JJ
#   rate/NN
#   for/IN
#   hundreds/NNS
#   of/IN
#   years/NNS
#   ./.
#   It/PRP
#   ’/VBD
#   s/JJ
#   easy/JJ
#   to/TO
#   find/VB
#   the/DT
#   statistics/NNS
#   on/IN
#   (ORGANIZATION NOAA/NNP)
#   ’/NNP
#   s/VBD
#   website/NN
#   ./.)

# %% [markdown]
# ## Vader Sentiment Scoring

# %%
# applying Sentiment Intensity Analyzer
sia = SentimentIntensityAnalyzer()
sia

# %%
# Running polarity Score
res = {}
for i, row in tqdm(commentsYoutube.iterrows(), total=len(commentsYoutube)):
    text = row['text']
    myid = row['text']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
res
# Out:
# {'Sea level has been suddenly rising? Sea levels have been rising at the same rate for hundreds of years. It’s easy to find the statistics on NOAA’s website.': {'neg': 0.0,
#   'neu': 0.903,
#   'pos': 0.097,
#   'compound': 0.4404},
#  'I&#39;ve been searching for a good video for my students, this actually helps, thank you !': {'neg': 0.0,
#   'neu': 0.57,
#   'pos': 0.43,
#   'compound': 0.807},
#  'Leave a mark': {'neg': 0.545, 'neu': 0.455, 'pos': 0.0, 'compound': -0.0516},
#  'Very informative and the best video on the topic ❤': {'neg': 0.0,
#   'neu': 0.656,
#   'pos': 0.344,
#   'compound': 0.6369},
#  'Let&#39;s face it: Root cause is human breeding run amok - overpopulation.<br>Until this is addressed, there&#39;s no hope of slowing down climate change.<br>E.g. India&#39;s population doubled between 1980 and 2020 ...<br>How many kids do you have? 😳': {'neg': 0.058,
#   'neu': 0.866,
#   'pos': 0.076,
#   'compound': 0.1779},
#  'Great propaganda! 😂': {'neg': 0.313,
#   'neu': 0.0,
#   'pos': 0.687,
#   'compound': 0.5255},
#  'CLIMATE CHANGE WAS INVENTED BU OUR CORRUPT GOVERNMENT, TO GAIN MORE AND MORE CONTROL !<br>WHAT A BUNCH OF BULLSHIT- REAL SCIENTISTS SAY THIS IS NOT TRUE ! CLIMATE CHANGE IS ABOUT GOVERNMENT CONTROL !!!': {'neg': 0.206,
#   'neu': 0.695,
#   'pos': 0.099,
#   'compound': -0.6643},
#  'It’s BS….that’s what climate change is….,I will break it down for you….Summer, winter, spring, and fall.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  '❤': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#  'These crush courses are great 👍, if you subtitle them as we would be a great help for all....❤❤❤❤❤❤❤': {'neg': 0.06,
#   'neu': 0.528,
#   'pos': 0.411,
#   'compound': 0.8834},
#  'Yes.': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4019},
#  'Ti is the latest war on the human race. And it is about 💸💸💸💸💸💸💸💸💸💸💸💸 money making machine for a few people of this world.Ok so the human race can help reduce pollution on the planet! There is technology available to day to reduce pollution on coal powered power stations and on cars trucks motorcycles and so on but the governments of the world are not interested in this technology Because no one wonted to Pay for it .cost 20 dollars per unit for cars !trucks ! Motorcycles!and son But nothing from Anyone .So as fare as I can see the Government&#39;s of this world are full of B.S. This is about Ajender 21 30 is alive an well as you can see.population control and population reduction in the world.': {'neg': 0.079,
#   'neu': 0.864,
#   'pos': 0.057,
#   'compound': -0.4597},
#  'A scam so your government can keep you in fear': {'neg': 0.496,
#   'neu': 0.504,
#   'pos': 0.0,
#   'compound': -0.7845},
#  'Is climate change different than Global Warming? <a href="https://youtu.be/bpSXbPbCuEM">https://youtu.be/bpSXbPbCuEM</a>': {'neg': 0.0,
#   'neu': 0.833,
#   'pos': 0.167,
#   'compound': 0.1531},
#  'Humans are Destroying the Natural Environment!!! 🛢🏭☠': {'neg': 0.374,
#   'neu': 0.418,
#   'pos': 0.209,
#   'compound': -0.4545},
#  'Coal and oil org dislike this video😂': {'neg': 0.302,
#   'neu': 0.698,
#   'pos': 0.0,
#   'compound': -0.3818},
#  'Malachi 4:1': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Stopped War. 👌': {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.7003},
#  'Think of current climate change as being global warming due to the amplification of the greenhouse effect due to an increase in greenhouse gases. If you understand the physics of the greenhouse effect as being the inhibition of infrared light (heat) from passing freely thru the atmosphere, thus resulting in a blanketing effect, then you’re all set to proceed to applying this knowledge (and sharing it with others).': {'neg': 0.034,
#   'neu': 0.837,
#   'pos': 0.13,
#   'compound': 0.7269},
#  'Thank You Very Very Much!<br>🙏': {'neg': 0.0,
#   'neu': 0.589,
#   'pos': 0.411,
#   'compound': 0.4199},
#  'BURNINGEARTH': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Thebutningearth': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  '<b>Reaserch needed how wars, regional conflicts, oil depots bombing, frequent war exercises affect the CLIMATE CHANGE</b><br>So peace treaties, denuclearisation, final border lines drawn needed to end the annoymities, greed of economy selling arms need ro get over.<br>Focus on new techs on spaceships to travel at almost the speed of light to land on Earth like planets.': {'neg': 0.186,
#   'neu': 0.727,
#   'pos': 0.087,
#   'compound': -0.7783},
#  'I woyld like more details from the video... eg. How much does war and the military industry contribute to global emissions?<br><br>How much energy could be saved if IoT, internet streaming etc. was halted? (All that green google-windmill energy could instead be used where fossil fuel is used?<br><br>To which extend does solar storms, radiation etc. influence the temperature on earth over time?<br><br>Has the temparature been rising the centuties just before the industrial revolution, and how much - and why?<br><br>How much does the 1 pct. most rich people contribute to ressource usage and thereby co2 contribution?<br><br>How much natural co2 does nature release through forest fires, volcanos, wild life etc.?': {'neg': 0.033,
#   'neu': 0.81,
#   'pos': 0.157,
#   'compound': 0.9127},
#  'Yeah': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296},
#  'C                                                         Global Warming Will End---God&#39;s Way<br><br>     The Bible tells us that &quot;the Former of the earth and the Maker of it.... did not create it simply for nothing.&quot; (Isaiah 45:18) The Bible also says: &quot;The earth endures forever.&quot;----Ecclesiastes 1:4, The New English Bible. <br><br>     Yes, God will not allow the earth to be uninhabitable. Rather, he will intervene in human affairs and bring an end to failed human rule and those who have no regard for the earth. At the same time, he will preserve alive all who lead morally upright lives and sincerely want to please him. Says Proverbs 22:21, 22: &quot;The upright are the ones that will reside in the earth, and the blameless are the ones that will be left over in it. As regards the wicked, they will be cut off from very earth; and as for the treacherous, they will be torn away from it.&quot;': {'neg': 0.098,
#   'neu': 0.798,
#   'pos': 0.104,
#   'compound': -0.0207},
#  'Rev 13:8 KJV<br>And all that dwell upon the earth shall worship him, whose names are not written in the book of life of the Lamb slain from the foundation of the world.<br><br>35a_Aims of the Papacy <br>Great Controversy (1911) Ellen G. White<br><a href="https://youtu.be/FOXSM3hpq98">https://youtu.be/FOXSM3hpq98</a><br>35b<br><a href="https://youtu.be/nICCs1VMBno">https://youtu.be/nICCs1VMBno</a>': {'neg': 0.0,
#   'neu': 0.917,
#   'pos': 0.083,
#   'compound': 0.4019},
#  'Stop SUVs. Plant more trees': {'neg': 0.355,
#   'neu': 0.645,
#   'pos': 0.0,
#   'compound': -0.296},
#  'it is not carbon dioxide but  carbon monoxide that comes from cars vehicles': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'This video is good': {'neg': 0.0,
#   'neu': 0.508,
#   'pos': 0.492,
#   'compound': 0.4404},
#  'Big up from Jamaica': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Los más codiciosos y avariciosos del planeta son los responsables de estos cambios y estoy hablando de los billonarios que pueden comprar países enteros, mientras siga imperando el sistema capitalista en el planeta, seguirá estando en desequilibrio el planeta, aquí los únicos que pueden hacer cambios verdaderos son los grandes corporativos dirigidos por estos billonarios dueños de países enteros, que muy cómodamente responsabilizan al ciudadano de a pie, que muchas veces no sabe ni donde esta parado.': {'neg': 0.029,
#   'neu': 0.971,
#   'pos': 0.0,
#   'compound': -0.296},
#  'free this world with war and atomic bombs. otherwise whatever you do. its not useful. anyway ultimately this world is going to its end. the day of judgment is coming very soon. be prepare yourself for next life. either in paradise or hell. if you are not a believer of GOD. then consider Stephen hawking wording. that this earth could be destroyed next one thousands years.': {'neg': 0.201,
#   'neu': 0.708,
#   'pos': 0.092,
#   'compound': -0.8386},
#  'I like its just a little to long': {'neg': 0.0,
#   'neu': 0.667,
#   'pos': 0.333,
#   'compound': 0.3612},
#  'Good Effort and much needed content': {'neg': 0.0,
#   'neu': 0.633,
#   'pos': 0.367,
#   'compound': 0.4404},
#  'Climate change cause to HEAT&amp;WASTE  Generated centre likely big cities. So ecofriendly lifestyle  as solutions.': {'neg': 0.0,
#   'neu': 0.892,
#   'pos': 0.108,
#   'compound': 0.1779},
#  'Ok for one  Great Barrier Reef have never been big then now. and never been more  arctic and Antarctic Ice , since humans have been around if you want to try and shut some one up at lest have your facts strait ... I am dun talking with you as you clearly just have a agenda and no knowledge of what you speak  The sky&#39;s are falling the sky&#39;s are falling you coward ! stop trying to scare people with lies !!!!!!!!!!!!!!!!!!!!!!!!!!!!! every stupid prediction you people come up with fails and dose the opposite of what you say are you not tired of being wrong or would you just rather Arson in all of Canada&#39;s forests to try and prove your agenda  Give it up move on to something new more real !!!!!!!!!!!!!!!!!!!!!!!': {'neg': 0.184,
#   'neu': 0.734,
#   'pos': 0.082,
#   'compound': -0.9308},
#  'Climate Change is bulshit propaganda for excuse to raise taxes by socialist left wing governments .': {'neg': 0.123,
#   'neu': 0.798,
#   'pos': 0.08,
#   'compound': -0.1779},
#  'It&#39;s sad that all these world leaders and the United Nations haven&#39;t really done anything to stop climate; the worst part is that they knew about climate change for more than 20 years and nothing is done. They always talk about how bad climate change is and don&#39;t really do anything.': {'neg': 0.209,
#   'neu': 0.746,
#   'pos': 0.045,
#   'compound': -0.8779},
#  'More fake science and baseless fearmongering about nothing!': {'neg': 0.345,
#   'neu': 0.655,
#   'pos': 0.0,
#   'compound': -0.5697},
#  'If producing (releasing/unlocking) CO2 is so bad for the world why don&#39;t we have a socially woke  campaign to ostracize and persecute people who buy and consume Coca Cola, Pepsi etc?   Surely the mass production and distribution of CO2 in this way is a crime against the planet that Climate change believers and the UN should move to shut down': {'neg': 0.163,
#   'neu': 0.794,
#   'pos': 0.043,
#   'compound': -0.8478},
#  'People that believe in climate change are just as dumb as the people believe that the earth is flat.': {'neg': 0.155,
#   'neu': 0.845,
#   'pos': 0.0,
#   'compound': -0.5106},
#  'so full of crap stop pushing this lie !!!!!!!': {'neg': 0.471,
#   'neu': 0.529,
#   'pos': 0.0,
#   'compound': -0.7377},
#  'Is the climate changing,..??..  Yes,.....     Is this a crisis,..??  No,....    it&#39;s the weather,.....': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'A hoax of grand proportions.': {'neg': 0.296,
#   'neu': 0.282,
#   'pos': 0.423,
#   'compound': 0.2263},
#  'Climate Change has since earliest written history of urbanisation of Man Kinds as phenomenon, is a present danger and existential threat to human Urban Habitation and intrinsic globalist military industrial economy, not a present danger and existential threat to the Human Species per say.': {'neg': 0.264,
#   'neu': 0.736,
#   'pos': 0.0,
#   'compound': -0.9274},
#  'It is written in the Bible that there will be no global chaos until the Antichrist appears beware one-third of Earth will be desolate': {'neg': 0.211,
#   'neu': 0.789,
#   'pos': 0.0,
#   'compound': -0.7096},
#  '🐶hi ClickView (you don&#39;t have to do a Q&amp;A video but) do you think you&#39;re a good person? if so do you think there&#39;s an afterlife? also i&#39;m not better than anybody else.': {'neg': 0.069,
#   'neu': 0.837,
#   'pos': 0.094,
#   'compound': 0.2153},
#  'I need citations or references 😭': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Why Do We Have to Have Natural Disasters?<br><br>We receive major blows from nature ultimately in order to shake us out of the state where we live according to an egoistic paradigm—with exploitation, manipulation and hatred dwelling in our connections—to a state where we positively connect, as described by the words, “as one man with one heart,” i.e., as a single well-oiled interconnected and interdependent system.<br><br>In other words, if we shared a harmonious and balanced connection to each other on the human level, then the balance at our level would ripple throughout nature and we would experience nature harmoniously and peacefully, and natural disasters, as we call them, would become a thing of the past.<br><br>We would be wise to pay attention to the future states that we can achieve out of such blows: that the blows come to shake us out of our current dreamlike state in our egoistic attitudes to each other, and wake us up into an opposite harmonious and peaceful world.<br><br>In fact, we live in a world that is all good, and only we human beings give the world a negative form in our egoistic attitudes to each other. The time is nearing when we will awaken to the need to stop relating to each other through egoistic lenses—where we each prioritize self-benefit at others’ expense—and instead relate patiently to each other with positive, kind and caring attitudes.<br><br>If we made such a switch, we would bear witness to a good life, the likes of which we have never before experienced. We should thus try to reach such relations as quickly as possible.': {'neg': 0.069,
#   'neu': 0.764,
#   'pos': 0.167,
#   'compound': 0.9812},
#  'Hi creator, this is great video to explanation about climate change. Can i use this video to do my presentation? i have presentation about climate change. Don&#39;t worry, i will mention the creator of this video. Many thanks to you.': {'neg': 0.066,
#   'neu': 0.774,
#   'pos': 0.159,
#   'compound': 0.6249},
#  'Climate change is really chemtrails and HAARP which is weather manipulation by your govt. It&#39;s bs to bring in carbon taxes, basically to tax the air you breathe.': {'neg': 0.075,
#   'neu': 0.925,
#   'pos': 0.0,
#   'compound': -0.296},
#  'Climate change <br><br>Take a look at the world around you, The environment is just like any human or animal.<br>It is alive; When we litter on the ground use cars with ,\xa0Or burn down a forest and the earth feels pain. And think about it, We have to live here, does it really make sense to damage the place we\xa0\xa0Live on. If the whole world gathered together we could get it done in hours.<br><br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0But that’s just pushing it; But seriously if we want to preserve our\xa0<br><br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Environment and our lives we must work as a unit if we want to get things\xa0<br><br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Done. Then the environment would become beautiful like something out of\xa0<br><br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0A Fairy tale story.': {'neg': 0.049,
#   'neu': 0.835,
#   'pos': 0.116,
#   'compound': 0.8294},
#  'Mostly bullshit': {'neg': 0.792,
#   'neu': 0.208,
#   'pos': 0.0,
#   'compound': -0.5859},
#  'Climate change is normal,taxing people to fix it is the biggest scam of our generation!': {'neg': 0.222,
#   'neu': 0.778,
#   'pos': 0.0,
#   'compound': -0.6114},
#  'THE CLIMATE CHANGES TOPICS BE EXPLAINED IN SCHOOL CURRICULUM': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Climate change is caused by cycles of solar activity not human activity. Greedy profiteers want you to think otherwise so they can get richer.': {'neg': 0.0,
#   'neu': 0.71,
#   'pos': 0.29,
#   'compound': 0.7321},
#  'Chemtrails is cloud seeding now well documented weather manipulation using harmful dry ice, hygroscopic flares and silver iodine. The CSIRO and militaries toxic secrets raise red flags over everything the public has fully known about this topic now... Environmental &quot;control&quot; of people has crossed over this era has blurred the lines of truth imo': {'neg': 0.038,
#   'neu': 0.885,
#   'pos': 0.076,
#   'compound': 0.296},
#  'People tend to only show concern when major events or personal circumstances affect them. As humans, we often prioritize our own interests and fail to extend the same level of care and concern to others. This raises the question: why is it so hard to care for others? Perhaps it&#39;s because there&#39;s no monetary reward for doing so. However, if we want to make the world a better place, we need to start caring more. Though it may be challenging, it&#39;s important to start taking action now. After all, if we don&#39;t start now, when will we?': {'neg': 0.065,
#   'neu': 0.718,
#   'pos': 0.216,
#   'compound': 0.9371},
#  'Climate change <br>Climate change is a global issue and we must work together to save our world but what exactly is climate change  our planet&#39;s climate has changed throughout history  alternating ice ages and warmer periods earth has been through at least  5 Major ice ages with the last one ending  12,000 years ago so if the climate has always changed  why is climate change such a big issue today?  Since the start of the industrial revolution in 1760 earths average has risen  faster than ever before this effect is known as global warming and it&#39;s caused by the increase of green house immersion(?)  from human activity  GREENHOUSE GASES occur naturally on our planet but human activities  such as the burning of fossil fuels, agriculture, deforestation  and the decomposition of waste in landfills have increased  the amount of green house gases dramatically  green house gases act like a blanket around earth trapping the heat from the Sun&#39;s rays  this is called the green house effect  thanks to this effect  earth has just the right  temperature  for life to thrive on it unlike other planets in our solar system  however if the greenhouse effect becomes too strong it starts to cause issues  the increased  temperatures we are experiencing now are causing ice in the artic and Antarctica  as well as glaciers and snow around the world  to melt the water created by the melting ice pours into the oceans causing sea levels to rise this puts all islands in danger of disappearing  especially those in the Pacific and Caribbean ranges rising sea  levels  are also causing devastating floods in countries like China, indonesia,philippines, malaysia, and thailand not only are these floods a direct Hazzard  to humans but can also destroy crops and farms used to feed the population another effect  of the rising temperatures is that oceans warm up and evaporate faster than normal increasing the occurrence of severe storms and heavy rainfall global warming is making weather more  extreme  bringing longer droughts and heatwaves the loss of soil moisture  and the high temperatures increase the risks of wildfire too the high temperatures on both land and in our oceans  effect  earths delicate ecosystems many animals are forced to migrate  to other areas to survive  while others are  loosing their habits and dying  so can we do anything  to stop the effects of climate change  climate change has already reached a point that humanity has never experienceed before  however  the future of our planet  is in our hands communities must make smart choices and tackle this issue with  environmentally friendly actions  some solutions to limit global warming  include : switching from burning  fossil fuels to renewable and Greener energy  sources  like solar hydroelectric or wind energy  reducing the emissions  caused by  industryof transportation by investing into greener technology and limiting the deforestation of land and investing in more space efficient forms of agriculture  like vertical farming  these are all big solutions but there are also smaller things that you could easily do at home for example  recycling , composting your organic waste eating more vegetables and fruits and fewer meat and dairy products saving electricity and buying things that last longer or that can be reused people around the world are working together  to innovate engineer  and develop solutions for the issue of climate change <br>Bhutan  is the world&#39;s most  carbon-negative  country  Costa Rica  has achieved 99% renewable energy  and now China is the world leader in wind power  climate change is a global issue and our future depends on the actions we take today': {'neg': 0.057,
#   'neu': 0.812,
#   'pos': 0.13,
#   'compound': 0.9905},
#  'The problem has been well known for at least 20 years now and yet it remains largely unaddressed in most parts of the world. The explosive population growth along with the increased demand for energy consumption has not been the least affected by western world campaigns and switching to electric cars is not going to save earth, or the human species. There are still entire continents where the word pollution remains more or less an unknown, so unless the whole world &#39;lifts together&#39; we reman doomed.': {'neg': 0.112,
#   'neu': 0.783,
#   'pos': 0.105,
#   'compound': -0.3987},
#  'Very helpful ❤. Currently studying for my test. I&#39;m a marine biology student.': {'neg': 0.0,
#   'neu': 0.781,
#   'pos': 0.219,
#   'compound': 0.4754},
#  'It&#39;s crucial that we take action to mitigate the effects of climate change, whether it&#39;s through reducing our carbon emissions, promoting renewable energy, or advocating for policy changes.❤': {'neg': 0.0,
#   'neu': 0.85,
#   'pos': 0.15,
#   'compound': 0.5574},
#  'Plastic pollution': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'This is the best explanation on this video, thank you very much': {'neg': 0.0,
#   'neu': 0.599,
#   'pos': 0.401,
#   'compound': 0.7717},
#  'Thank you': {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612},
#  'Haha all a scam. When I was in school the world was supposed to be gone by now. The earth is always changing how do you think the ice age left? Wake up people abs stop fearing everything  they push your way line a little kid. Wake up.  California pushing electric cars where the batteries cause more harm, and that can’t even handle a warm day without blackouts. Scam!!!': {'neg': 0.178,
#   'neu': 0.723,
#   'pos': 0.099,
#   'compound': -0.8111},
#  'Injustice &amp; Climate change??????????': {'neg': 0.608,
#   'neu': 0.392,
#   'pos': 0.0,
#   'compound': -0.6868},
#  'War &amp; Climate change???????': {'neg': 0.618,
#   'neu': 0.382,
#   'pos': 0.0,
#   'compound': -0.7059},
#  'The earth has had 10°c rises in 40 years in the past. That one fact alone decimates the human caused global warming hoax. People like John Kerry are making a fortune on this scam. Now all the elites are taking your tax dollars telling you it will save the planet. Look up catastrophism. It&#39;s a thing this planet and all other planets in our solar system go through. Limited deforestation is definitely good. Stop dumping garbage is another good idea. China is the world leader in coal plants. This video is pure propaganda and nothing more. WTFU people. Read! Research!': {'neg': 0.148,
#   'neu': 0.719,
#   'pos': 0.134,
#   'compound': -0.1677},
#  'Omg, THANK YOU, THE BEST PERSON PERSON IN THE WORLD! Really, you explained everything straight forward and without any unwanted stuff, thanks to you I understood how this enormous circle works)': {'neg': 0.0,
#   'neu': 0.626,
#   'pos': 0.374,
#   'compound': 0.9316},
#  'Climate change is a hoax. John Kerry and Al Gore are liars.': {'neg': 0.379,
#   'neu': 0.621,
#   'pos': 0.0,
#   'compound': -0.6705},
#  'The bible tells you what happening': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  '👉The UNs Mysterious Plan to Fight Climate Change Revealed Here: <a href="https://youtu.be/AqVvi-LDPzw">https://youtu.be/AqVvi-LDPzw</a>': {'neg': 0.191,
#   'neu': 0.809,
#   'pos': 0.0,
#   'compound': -0.3818},
#  'User is CHIAZ6630A': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'YOU R IN MY SLS user': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Cowabummer!!!!!!!!!!!!!!!': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'No such thing.': {'neg': 0.524,
#   'neu': 0.476,
#   'pos': 0.0,
#   'compound': -0.296},
#  'Share this with family and friends 🚨🚨🚨': {'neg': 0.0,
#   'neu': 0.485,
#   'pos': 0.515,
#   'compound': 0.6486},
#  'A way to scam billions of dollars with fear mongering....?': {'neg': 0.496,
#   'neu': 0.504,
#   'pos': 0.0,
#   'compound': -0.7845},
#  'Bullshit': {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5859},
#  'Had snow for 6 straight months here in So. Utah. When the hell is this climate change going to show up????': {'neg': 0.218,
#   'neu': 0.707,
#   'pos': 0.075,
#   'compound': -0.6868},
#  'What a steaming load. We&#39;re supposed to care about &quot;climate change&quot;, when the rich greedy people fly in their private jets to talk about how the common person is causing the temperature to go up and down. It&#39;s hilariously sad, really.': {'neg': 0.112,
#   'neu': 0.747,
#   'pos': 0.141,
#   'compound': 0.34},
#  'sub-saharan development is literally killing us....where in the developed world, sub saharan&#39;s terroism is driving urban sprawl.<br>oddly, climate change has been primarily caused by the fossil fuels used to transform once topsoil carbon sink into more starving methane emitters in sub-saharan africa. <br>oh sure,<br>development seems to be the only way to figure out how many of them actually live in africa.....but is that really worth it?': {'neg': 0.103,
#   'neu': 0.867,
#   'pos': 0.03,
#   'compound': -0.743},
#  'Palestine was a unavoidable accident.Better get your act together.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'What is climate change? A big hoax. I&#39;m 76, been hearing this lie since I was in grade school. I&#39;m 76, been hearing this lie since I was in grade school. I live in Ohio, it&#39;s still hot in the summer,  cold in the winter, rains a lot in the spring and is just right for football in the fall, go BUCKS!!!': {'neg': 0.05,
#   'neu': 0.95,
#   'pos': 0.0,
#   'compound': -0.4545},
#  'Thank you ClickView.<br>Your video on Climate change is very informative and you have provided the solutions to the problem. I think every country knows about the solution but if these solutions are followed then don&#39;t you think the massive population will be left with no alternative. Please do not take me in a negative sense as I am mentioning on my personal experience. My cousin is a butcher and he is into this profession since childhood now all of a sudden he will be asked to leave his profession then I thing everyone associated with his output will be in a state of doldrums. He is supplying flesh to different organization and the supply in not in kgs but tonnes. it is the duty of every individuals to take the ownership then situation will come to a normal. Once I had a very rough argument with a chicken seller few years ago from then onwards I left consuming chicken, even during any occasion I would go for some other food item but not chicken. I think I did my part. If everyone takes the ownership then there will be a change sooner or later. Finally your video is an eye-opener and it should be brought to the notice of the legislature who can make some laws and the executive will have some binding effect. I believe it is just the game of Demand and Supply.<br><br>Best Wishes.<br>Khwaja Ram.': {'neg': 0.07,
#   'neu': 0.889,
#   'pos': 0.041,
#   'compound': -0.8256},
#  'I&#39;m amazed at how calm he is as he is narrating this.': {'neg': 0.0,
#   'neu': 0.645,
#   'pos': 0.355,
#   'compound': 0.6705},
#  'It&#39;s a wank': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Fly a private jet. That helps! Big business warship money and power.  Electricity benefits A.I., Robots, technology. Will we ? Are we being replaced. See eye see.': {'neg': 0.058,
#   'neu': 0.754,
#   'pos': 0.188,
#   'compound': 0.5848},
#  'Climet change caused by G7 gor their industrialization. They must give sanction': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Now almost every day ireland is covered in clouds': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Climate change isn&#39;t caused by hotter temperatures but by increased oceanic swelling.  Such oceanic swelling is what drives extreme weather patterns.  Ships wakes, transport air pressure changes, wind power all contribute to increased waves and therefore extreme weather patterns': {'neg': 0.063,
#   'neu': 0.816,
#   'pos': 0.12,
#   'compound': 0.3612},
#  'If the richest are so concerned about climate change that they are contributing the most, why no single rich person suggests to limit everyone plane journeys say to 40k kilometers a year? They instead want majority to eat bugs and warms instead to &#39;save&#39; the planet from their pollution. Just liers!': {'neg': 0.043,
#   'neu': 0.774,
#   'pos': 0.184,
#   'compound': 0.8027},
#  'Fun fact, every climate fearmonger has an iphone': {'neg': 0.0,
#   'neu': 0.68,
#   'pos': 0.32,
#   'compound': 0.5106},
#  'The weapons with which the bourgeoisie felled feudalism to the ground are now turned against the bourgeoisie itself.<br>Communist manifesto': {'neg': 0.22,
#   'neu': 0.78,
#   'pos': 0.0,
#   'compound': -0.5859},
#  'Lunatic people?<br>Believes and worship the<br>Climate Change.<br>And the right word to describe them, FoolS,.,.': {'neg': 0.195,
#   'neu': 0.671,
#   'pos': 0.134,
#   'compound': -0.25},
#  'I&#39;d like to present you my new song &quot;SOS PLANET&quot;. This song addresses the urgent changes that Humanity must carry out. Attitudes must shift in order to avoid the imminent and irremediable destruction of Nature and Planet Earth. The song imagines the last surviving man on Earth as he apologizes for humanity’s mistakes. “SOS Planet” serves as a wake-up call to everyone, in particular to world leaders. &quot;Take care of the earth. It&#39;s our home.”  I hope you like it<br><a href="https://www.youtube.com/watch?v=2MLZ6u49_GM">https://www.youtube.com/watch?v=2MLZ6u49_GM</a>': {'neg': 0.088,
#   'neu': 0.724,
#   'pos': 0.188,
#   'compound': 0.8205},
#  'What is climate change summer fall winter spring that&#39;s real climate change 4 times a year': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Who do you think took care to plan it before you guys got here with the climate change stuff I mean think about it volcanoes erupting didn&#39;t kill off the planet the planet is a living world and does not need someone like Bill Gates or John Kerry to take care of it the planet will be here for millions of years more then you two will and has great without your input or help. If the both of really want to help Humanity grab your bottom lip and pull it up over your head and swollen. Thank you very much': {'neg': 0.058,
#   'neu': 0.771,
#   'pos': 0.171,
#   'compound': 0.9039},
#  'Global Warming is a lie.': {'neg': 0.0,
#   'neu': 0.652,
#   'pos': 0.348,
#   'compound': 0.1531},
#  'Our duty is to warn them however if they continue on a path of folly then we can consider ourselves released from any obligation to save them.': {'neg': 0.049,
#   'neu': 0.839,
#   'pos': 0.112,
#   'compound': 0.4215},
#  'Climate change by man made and preventable causes is causing the desertification of sub-Saharan Africa.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'that man made causes are destroying the ecology. they can be prevented to save the planet from further harm.': {'neg': 0.269,
#   'neu': 0.568,
#   'pos': 0.163,
#   'compound': -0.5859},
#  'for climate change activists this is like a post mortem rather than a diagnosis': {'neg': 0.0,
#   'neu': 0.815,
#   'pos': 0.185,
#   'compound': 0.3612},
#  'ecological hazard looming over europe: france, germany and others': {'neg': 0.158,
#   'neu': 0.842,
#   'pos': 0.0,
#   'compound': -0.128},
#  'europe better reduce their emissions and pollution soon before the climate disaster strikes them dearly': {'neg': 0.283,
#   'neu': 0.472,
#   'pos': 0.245,
#   'compound': -0.2263},
#  'corelation between climate change and the disaster striking humanity is becoming clearer everyday... that they are man made causes behind climate change and disaster like CO2 emissions, water pollution, overfishing, among others.': {'neg': 0.207,
#   'neu': 0.73,
#   'pos': 0.063,
#   'compound': -0.7717},
#  'A 50% reduction in GHG.??   Not going to happen; China building more coal plants, India ditto, then there is Africa with all of them wanting Western world lifestyles !  Get ready for more warmth, failing crops, worldwide wars and starvation !': {'neg': 0.17,
#   'neu': 0.71,
#   'pos': 0.121,
#   'compound': -0.5154},
#  'What a total load of shyte. I threw my television in the bin over a decade ago. Thanks for reminding me what a wise move that was. Think I will skip the last hour 22 min of this fantasy.': {'neg': 0.0,
#   'neu': 0.842,
#   'pos': 0.158,
#   'compound': 0.7184},
#  'The only climate that needs to change is in Washington DC what this planet does has nothing to do with man if we could then the phony carbon credit system would work that just the riches way to not look hypacritical': {'neg': 0.0,
#   'neu': 0.867,
#   'pos': 0.133,
#   'compound': 0.7184},
#  'Earth will become like Mars in the future..': {'neg': 0.0,
#   'neu': 0.737,
#   'pos': 0.263,
#   'compound': 0.3612},
#  '😊': {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0},
#  'I noticed that our soil dries out far quicker than it used to. I guess the ground water no one replaces has its use too. <br>We are not only warming the atmosphere we are cooking the ground we walk on. <br>There&#39;s a reason we see more sink holes popping up everywhere too. <br>Our governments do nothing. Because it&#39;s too costly! Yet there&#39;s more millionaires and billionaires than ever before. Ironically oil companies are reaping the biggest profits ever. <br>We need to over throw governments. We won&#39;t of course so we will all go down with the ship. <br>The answer is not in preventing oil production first. We need fresh water from desalination plants. Carbon capture and carbon scrubbing. For that we need power. Until hydrogen or another viable green product is available  in bulk. We need to get moving quickly.': {'neg': 0.035,
#   'neu': 0.919,
#   'pos': 0.046,
#   'compound': 0.3658},
#  'Tree plantation can help us to perpetuate our climate from being worsted, we should be more aware of planting trees and saplings!<br>Every year there is a certain time comes when we can plant saplings and i think we should teach school students!!': {'neg': 0.0,
#   'neu': 0.87,
#   'pos': 0.13,
#   'compound': 0.6884},
#  'All the people who only live off the land suffer the most. I think going back to horse and buggy would be great. Everybody grow their own food. No more big companies or poisonous plants. But this will never happen, and the poor will suffer the most. God be with us all.': {'neg': 0.233,
#   'neu': 0.68,
#   'pos': 0.087,
#   'compound': -0.8577},
#  'Democratic elections have a very large carbon footprint compared to a dictatorship or a military coup.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Oh yeah? Who will stop those BIG MANUFACTURING COMPANIES Especially Manufacturing companies who produce PLASTIC MATERIALS and materials that could make the world more hotter? Oh wait let me answer that. . . . No one. Even the government cannot stop them because its BUSINESS.': {'neg': 0.148,
#   'neu': 0.806,
#   'pos': 0.047,
#   'compound': -0.5803},
#  'A lot of people call it GLOBAL WARMING. . . I call it TRANSITION. ICE AGE was over. Now, the world is transitioning itself from cold to hot climate.': {'neg': 0.0,
#   'neu': 0.911,
#   'pos': 0.089,
#   'compound': 0.3254},
#  'Per assurdo se eliminiamo tutta la co2 muoiono tutte le piante <br>Cloud seeding method involves. <br>Nel 2023 la massa ghiacciata della Groenlandia È AUMENTATA DEL 3%.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Please see the work of Professor William Happer Princeton University.': {'neg': 0.0,
#   'neu': 0.796,
#   'pos': 0.204,
#   'compound': 0.3182},
#  'How did the fossils get trapped in the permafrost if the temp is unprecedented ?': {'neg': 0.207,
#   'neu': 0.793,
#   'pos': 0.0,
#   'compound': -0.5267},
#  'This don&#39;t make sense ...they can create rain snow wind so give me a break with global warming It&#39;s BECAUSE they are creating it they are killing us': {'neg': 0.132,
#   'neu': 0.691,
#   'pos': 0.177,
#   'compound': -0.128},
#  'Ever consider that something more powerful and intelligent than man created this universe???': {'neg': 0.0,
#   'neu': 0.529,
#   'pos': 0.471,
#   'compound': 0.8358},
#  'Climate change as you call it can&#39;t be repaired from the ground..there&#39;s more damage from the burn off of rockets..thermogenic heat is burning up everything..good luck with all that emissions stuff..': {'neg': 0.098,
#   'neu': 0.817,
#   'pos': 0.085,
#   'compound': -0.1263},
#  'People still belive this BS?': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Its a lie, there is only 0.02% co2 in the atmosphere on this earth': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'before they made simtetic rubber plunging down its price n now sintetic palm oil.poor farmers': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'This is what happens when you don&#39;t listen to al gore': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'How are u gonna «\xa0avert\xa0» mainly natural climate change ???  How come all those different climate doomsday predictors think they are next to Jesus on the pedestal ?  A little less arrogance wouldn’t hurt !': {'neg': 0.309,
#   'neu': 0.631,
#   'pos': 0.061,
#   'compound': -0.8811},
#  'Telling the ever-hungry to stop eating will never happen; we&#39;ll just have to adapt to a warming world.': {'neg': 0.117,
#   'neu': 0.798,
#   'pos': 0.085,
#   'compound': -0.1531},
#  'My 7th grade science teacher told the class, when we’re his age, our home town will be 6 feet under water. That was in 1982…41 years ago.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'It&#39;s wild that you can watch the permafrost in real-time melt so fast': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'It’s clear and definite that warming causes more co2. In addition to the carbon released from the permafrost, the burning of fuel also releases Co2 and water vapour. <br><br>Now, if “Co2 causes warming” is also true, we are having a perpetual motion machine at work!<br><br>We all know PMM is not possible, so “co2 causes warming “ cannot be true! The “warming “ is definitely caused be other factors than GHG’s!!!<br><br>In logic, “C causes W, and W causes C” is a circular reasoning! It is wrong!': {'neg': 0.034,
#   'neu': 0.779,
#   'pos': 0.188,
#   'compound': 0.9056},
#  'Global warming?no such thing, the earth has been warming since the ice age, the earth will rectify it&#39;s self': {'neg': 0.0,
#   'neu': 0.918,
#   'pos': 0.082,
#   'compound': 0.1531},
#  'Earth has been cool and was due to warm up.  Alarmist ignorance.': {'neg': 0.159,
#   'neu': 0.573,
#   'pos': 0.268,
#   'compound': 0.1779},
#  'Depressing': {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.3818},
#  'Even if the Earth went CO2 neutral today we would still pass 2,0 degrees. We shall be lucky to stay below 3 degrees': {'neg': 0.0,
#   'neu': 0.882,
#   'pos': 0.118,
#   'compound': 0.4215},
#  '&quot;catastrophe&quot;😂😂😂😂😂😂😂<br>Even the IPCC says this sort of rhetoric is not helpful.': {'neg': 0.189,
#   'neu': 0.811,
#   'pos': 0.0,
#   'compound': -0.3252},
#  'The stupidity of some is infectious to the weak minded fools that believe that mankind can change the weather! Next time a hurricane comes, throw money at it and see if it will stop!': {'neg': 0.289,
#   'neu': 0.711,
#   'pos': 0.0,
#   'compound': -0.8953},
#  'If Humanity stopped burning fossil-fuels Today, its already too late....but 30 million internal-combustion vehicles- New Vehicles - hit the road in 2022. We&#39;re fucked.<br>Wish i was about 30yrs younger so i could watch, cuz it&#39;s gonna be epic.': {'neg': 0.053,
#   'neu': 0.947,
#   'pos': 0.0,
#   'compound': -0.2263},
#  'Just say know to climate hysteria. Chicken Little thought the sky was falling too!': {'neg': 0.285,
#   'neu': 0.715,
#   'pos': 0.0,
#   'compound': -0.5848},
#  'We need more misery in mountains 💫': {'neg': 0.444,
#   'neu': 0.556,
#   'pos': 0.0,
#   'compound': -0.6115},
#  'I ve been hearing predictions about loss of glaciers and polar caps and target dates for their disappearance for decades. It has not happened yet. There were predctions about cities and islands being submerged. Yet they are still there. When looking at the detailed history of recorded temperatures from around the world, I am more inclined to believe Clintel and its criticism of IPCC 6.': {'neg': 0.079,
#   'neu': 0.921,
#   'pos': 0.0,
#   'compound': -0.6369},
#  'In my town hundreds of people including myself have bought 100s of items of canned food, no store has any canned food for miles and miles, over the next year or two we are going to be needing these due to crops failures, whilst everyone is fighting I will have to safe guard my supply, a tin of baked beans can be sold for £7 per tin': {'neg': 0.108,
#   'neu': 0.852,
#   'pos': 0.041,
#   'compound': -0.5859},
#  '3 degrees by 2100... if we&#39;re lucky.': {'neg': 0.0,
#   'neu': 0.641,
#   'pos': 0.359,
#   'compound': 0.4215},
#  'Climate change is still a myth a story for children': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'As more electric cars come out, I burn more and more garbage, leaves, and plastic in my back yard to make up for the lost pollution.': {'neg': 0.087,
#   'neu': 0.913,
#   'pos': 0.0,
#   'compound': -0.3182},
#  'Techno-desperation and the failure from thousands of years of patriarchy.': {'neg': 0.268,
#   'neu': 0.732,
#   'pos': 0.0,
#   'compound': -0.5106},
#  'too late': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'WRONG! THERE IS NO CLIMATE CHANGE! THIS IS NORMAL AND PLEASE READ THE SCIENCE. YOU ARE CREATING ANARCHY.': {'neg': 0.241,
#   'neu': 0.574,
#   'pos': 0.185,
#   'compound': -0.3365},
#  'What a load of bo..ocks...<br><br>When you can peg everything on the one thing, it gives a good excuse not to look at other things!<br><br>Pegging the whole ecological problem on to climate, and the whole climate problem to carbon, and assume we can alter the former by raging war on the latter is insanity.': {'neg': 0.257,
#   'neu': 0.678,
#   'pos': 0.065,
#   'compound': -0.9259},
#  'Climate change is a lie Iv just done the maths <br>37.12 billion tonnes of co2 emissions per year world wide <br>1 tree absorbs 21 kgs of co2 <br>There are 3 trillion trees on earth give or take <br>So that’s 63 trillion kgs or 630 billion tonnes 🧐so the trees are removing all the  co2 never mind the grass and other shit': {'neg': 0.058,
#   'neu': 0.942,
#   'pos': 0.0,
#   'compound': -0.5574},
#  'I need you to save lives in the world...': {'neg': 0.0,
#   'neu': 0.686,
#   'pos': 0.314,
#   'compound': 0.4939},
#  'Just stop having children if you cant find water, it&#39;s not rocket science.  We rich countries are going to burn co2 to enjoy our privilege.  So please stop complaining about our good thing.': {'neg': 0.14,
#   'neu': 0.54,
#   'pos': 0.32,
#   'compound': 0.853},
#  'Table of Elements and Compounds in Air\r<br>Below is the composition of air in percent by volume, at sea level at 15 C and 101325 Pa.\r<br>\r<br>Nitrogen -- N2 -- 78.084%\r<br>Oxygen -- O2 -- 20.9476%\r<br>Argon -- Ar -- 0.934%\r<br>Carbon Dioxide -- CO2 -- 0.04%\r<br>Neon -- Ne -- 0.001818%\r<br>Methane -- CH4 -- 0.0002%\r<br>Helium -- He -- 0.000524%\r<br>Krypton -- Kr -- 0.000114%\r<br>Hydrogen -- H2 -- 0.00005%\r<br>Xenon -- Xe -- 0.0000087%\r<br>Ozone -- O3 -- 0.000007%\r<br>Nitrogen Dioxide -- NO2 -- 0.000002%\r<br>Iodine -- I2 -- 0.000001%\r<br>Carbon Monoxide -- CO -- trace\r<br>Ammonia -- NH3 -- trace': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'One of the biggest reasons thing are out of control is that we realistically deny that we are doing it in the most Ironic way&gt;&gt;&gt; she said the Glaciers are melting because of Global Warming,,,,WRONG,,, we are causing the glaciers to melt, we are causing the air to be polluted, we are the cause of wildfires, flooding, giant huricanes, ect ect ect. Our entire culture and system separates us from a global warming phenom. This is where most everyone feels it is no responibility of our. OWN IT! Then we will change!!! The system has labeled it, and made it impersonable without blame.': {'neg': 0.096,
#   'neu': 0.871,
#   'pos': 0.033,
#   'compound': -0.7861},
#  'Percent of CO2 in our atmosphere is .04%! If it gets below .02%, plants and crops will start dying then us because of no food!': {'neg': 0.104,
#   'neu': 0.896,
#   'pos': 0.0,
#   'compound': -0.4184},
#  'Direct Energy Weapons (DEW)- Sustainable development =culling us useless eaters.': {'neg': 0.385,
#   'neu': 0.473,
#   'pos': 0.142,
#   'compound': -0.5574},
#  'If we don&#39;t act now to reverse climate change then we won&#39;t have a planet left to depopulate.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'I don’t give a rats about climate change. I care about corruption in media and government. We can’t trust politicians who keep throwing money at friends and relatives who pay for their campaigns.  We need a solution not propaganda.  So I don’t agree to get onboard with a bunch of alarmists who have no solutions.': {'neg': 0.091,
#   'neu': 0.621,
#   'pos': 0.288,
#   'compound': 0.9085},
#  'My spirit will be most amused to return to earth within the next 300 years to see New York City streets covered by the ocean.': {'neg': 0.0,
#   'neu': 0.828,
#   'pos': 0.172,
#   'compound': 0.5849},
#  'Please make another failed doomsday prediction so when it actually happens nobody will pay attention...': {'neg': 0.39,
#   'neu': 0.505,
#   'pos': 0.106,
#   'compound': -0.7351},
#  'I keep hearing about how much cheaper wind and solar are but for some reason my electric bill doubled? Weird...': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Half of the entire solution is putting a high price on carbon emissions from fossil fuels.  The best way to do that is charge fossil fuel producers a steadily rising carbon fee and return all the money to everyone in equal shares each month.  That supports the high price that is necessary.  Use a CBAM to charge that price on imports from free-polluting countries to strongly encourage them to match the price.  The IPCC says we need a price of $135 per ton of CO2 by 2030 and rising $10 a year after to even have a chance to hold warming to 1.5˚C.  In addition to pricing carbon, a hundred other complementary policies are needed.  But any combination that fails to include a strong carbon price has no chance of reducing emissions as fast as we need for our safety.  Please learn about Carbon Fee and Dividend with Border Carbon Adjustments, and ask your elected leaders to pass legislation to do it now.': {'neg': 0.037,
#   'neu': 0.805,
#   'pos': 0.158,
#   'compound': 0.9451},
#  'The 50 Gigatonne decadal methane dead pulse scenario was posited by four Arctic specialists in 2008 and is now considered plausible by Met Office scientists<br><br>The paper noted that while seabed permafrost underlaying most of the East Siberia Arctic Shelf (ESAS) was previously believed to act as an &quot;impermeable lid preventing methane escape,&quot; new data showing &quot;extreme methane supersaturation of surface water, implying high sea-to-air fluxes&quot; challenged this assumption. Data showed:<br><br>    &quot;Extremely high concentrations of methane (up to 8 ppm) in the atmospheric layer above the sea surface along with anomalously high concentrations of dissolved methane in the water column (up to 560 nM, or 12000% of super saturation).&quot;<br><br>One source of these emissions &quot;may be highly potential and extremely mobile shallow methane hydrates, whose stability zone is seabed permafrost-related and could be disturbed upon permafrost development, degradation, and thawing.&quot; Even if the methane hydrates are deep, fissures, taliks and other soft spots create heat pathways from the seabed which warms quickly due to shallow depths. Various mechanisms for such processes have been elaborated in detail.<br><br>The paper then posits the plausibility of a 50 Gigatonne (Gt) methane release occurring abruptly &quot;at any time.&quot; Noting that the total quantity of carbon in the ESAS is &quot;not less than 1,400 Gt&quot;, the authors wrote:<br><br>    &quot;Since the area of geological disjunctives (fault zones, tectonically and seismically active areas) within the Siberian Arctic shelf composes not less than 1-2% of the total area and area of open taliks (area of melt through permafrost), acting as a pathway for methane escape within the Siberian Arctic shelf reaches up to 5-10% of the total area, we consider release of up to 50 Gt of predicted amount of hydrate storage as highly possible for abrupt release at any time. That may cause ∼12-times increase of modern atmospheric methane burden with consequent catastrophic greenhouse warming.&quot;<br><br>So the 50 Gt scenario used by the new Nature paper does not postulate the total release of the ESAS methane hydrate reservoir, but only a tiny fraction of it.<br><br>The scale of this scenario is roughly corroborated elsewhere. A 2010 scientific analysis led by the UK&#39;s Met Office in Review of Geophysics recognised the plausibility of catastrophic carbon releases from Arctic permafrost thawing of between 50-100 Gt this century, with a 40 Gt carbon release from the Siberian Yedoma region possible over four decades.<br><br>Shakhova and her team have developed these findings from data derived from over 20 field expeditions from 1999 to 2011. In 2010, Shakhova et. al published a paper in Science based on their annual research trips which highlighted that the ESAS was a key reservoir of methane &quot;more than three times as large as the nearby Siberian wetland... considered the primary Northern Hemisphere source of atmospheric methane.&quot; Current average methane concentrations in the Arctic are:<br><br>    &quot;about 1.85 parts per million, the highest in 400,000 years&quot; and &quot;on par with previous estimates of methane venting from the entire World Ocean.&quot;<br><br>As the ESAS is shallow at only 50 metres, most of the methane being released is escaping into the atmosphere rather than being absorbed into water.<br><br>The existence of such shallow methane hydrates in permafrost - at depths as small as 20m - was confirmed by Shakhova in the Journal of Geophysical Research. There has been direct observation and sampling of these hydrates by Russian geologists in recent decades until now; this has also been confirmed by US government scientists.': {'neg': 0.03,
#   'neu': 0.933,
#   'pos': 0.037,
#   'compound': -0.0129},
#  'Only a global elitist could think up a plan to make the public believe that CO2, the building block of all carbon life on earth, is the enemy.  Only the leftists and their emotion based critical thinking could be fooled into believing such absurdity.  Want some truth on this nonsense?  Quit living in fear and watch the video by Greenpeace Co-founder Patrick Moore.': {'neg': 0.233,
#   'neu': 0.718,
#   'pos': 0.049,
#   'compound': -0.9274},
#  'fear mongering,,, woke agenda': {'neg': 0.516,
#   'neu': 0.484,
#   'pos': 0.0,
#   'compound': -0.4939},
#  'UN is a sold soul !! its puppet': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'The question I would like tabled by the media is as follows. A consensus by experts, say the industrial revolution started circa 1760 in the Northern Hemisphere. Therefore for two centuries Britain, France,USA, Italy ,Sweden et al. Were using fossil fuels and pumping green house gases into the atmosphere. There was no global warming<br><br>Then in the late 1980&#39; the western industralist&#39;s moved global manufacturing into the hottest part of the world. India , China, Vietnam etc.<br><br>Within 30 yrs the planet is suffering dramatic warming. Would the climate experts say this is a contributing factor? I would like know, because I think it is..': {'neg': 0.051,
#   'neu': 0.885,
#   'pos': 0.064,
#   'compound': 0.0772},
#  'Dams are to be removed by man or by Gaia you have that choice...it has begun the stripping away of your culture ...how dare you dim the flame ..<br>Your punishment will be severe': {'neg': 0.158,
#   'neu': 0.842,
#   'pos': 0.0,
#   'compound': -0.7003},
#  'It&#39;s time to close down the companies making cheap plastics and any shipping company dealing in them viva de gracious peoples 999': {'neg': 0.0,
#   'neu': 0.854,
#   'pos': 0.146,
#   'compound': 0.5574},
#  'Klimat zmienia się od powstania naszej planety, jest ona żywym organizmem. Zmienia się ustawienie względem Słońca , lądy względem siebie. Tylko my w swojej ułomności nie potrafimy się z tym pogodzić. A tak naprawdę gdyby całą ludzkość wyeliminować hipotetycznie to nasza Matka Ziemia w 100 lat posprzątałaby ten cały nasz bałagan. Majowie, Egipt i inne kultury możemy się tylko domyślać co się stało. Składali ofiary my płacimy kary klimatyczne i zostaje zapytać do czyjej kieszeni te pieniądze idą ,dla biednych, dla chorych? Odpowiedz sobie sam.': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'Does anyone still believe that catastrophe can be avoided? Seriously?': {'neg': 0.559,
#   'neu': 0.441,
#   'pos': 0.0,
#   'compound': -0.8343},
#  '100% PURE LIES.': {'neg': 0.639,
#   'neu': 0.361,
#   'pos': 0.0,
#   'compound': -0.5473},
#  'The biggest threat to humanity is mankind': {'neg': 0.362,
#   'neu': 0.638,
#   'pos': 0.0,
#   'compound': -0.5267},
#  'So you use solar panels build by child labor in China to capture plant food and store it underground to cash in on state subsidies? Amazing how this is accepted as environmentally friendly nowadays.': {'neg': 0.0,
#   'neu': 0.773,
#   'pos': 0.227,
#   'compound': 0.8442},
#  'This is based on free imagination and doomsday prophecy that only exists in the minds of sick people. It is pure lies and BS and are coming from indoctrinated children and activists.': {'neg': 0.272,
#   'neu': 0.649,
#   'pos': 0.079,
#   'compound': -0.7906},
#  'the planet will survive. humans, probably not': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'If I only care I would be crying and saying animals and mother nature is more important than humans no more important because if we didn’t live then the world would be different and in a bad way': {'neg': 0.195,
#   'neu': 0.642,
#   'pos': 0.163,
#   'compound': -0.343},
#  'This was foretold by Jesus. He told us the things that were going to happen. The earthquakes the floods all the changes that are happening. He is going to take out His Church and the great tribulation will begin. It will be like nothing ever before. He is coming. Do you know Jesus. He is the Creator God and He gave His Life on the cross. He gave His life for you. Don’t wait until it’s too late.': {'neg': 0.0,
#   'neu': 0.896,
#   'pos': 0.104,
#   'compound': 0.8271},
#  'Meanwhile in China...lets pump up more coal plants': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0},
#  'lmao united nations aint gonna do sh*t. not when the governments are lobbyed by big oil companies. the only solution is to destroy capitalism but it might be too late for that': {'neg': 0.062,
#   'neu': 0.772,
#   'pos': 0.166,
#   'compound': 0.4118},
#  'We started a chain reaction about 100 years ago that we wont be able to stop… global warming is here to stay… so enjoy what is left of the ride, it was nice while it lasted, whatever efforts they doing is just to make money… nothing serious, just corruption and power doing what they do best': {'neg': 0.0,
#   'neu': 0.782,
#   'pos': 0.218,
#   'compound': 0.9176},
#  'Just think of how many jobs could be created if we put solar and turbine energy factories throughout the country and every country. It would change the world in so many ways but we have these oil greedy corporations, millionaires and billionaires calling the shots in this country and our planet is coming to an end. It is crazy.  We have the resources to change the outcome but no one wants to admit it is a problem and we just keep going on like somehow it will solve itself. Pretty soon it will be too late and our children and grandchildren will not have a planet to live in, it will be uninhabitable. I shake my head when these people out here say “oh there is no such thing as global warning they just have you believe nonsense. They will say stuff like “ The earth will take care of itself as it has for thousands of years.”  We got people in office that think the same thing and spread this false narrative  to people who support them on the idea. It is like one of those movies where a scientist will be trying to warn the government about a disaster coming and the governor says come on I will not alarm people it will create chaos  and then the disaster comes and blows the governor away and people are screaming and running. This is what is happening and the thing about it is we could solve homelessness, poverty and climate change with one step and that is taking all these old run down factories you see everywhere and turning them into natural energy factories and hire people all people, build housing for the factory workers and that too could create jobs and build skills for some of the people that need to learn so they can gain employment. There is so much change that could happen if we moved to natural energy but we aren’t doing it WHY?  If it is money well look at the money we are spending on these disasters they aren’t cheap. We need to demand change on every state capital building  as a United World.': {'neg': 0.13,
#   'neu': 0.727,
#   'pos': 0.144,
#   'compound': 0.2959},
#  'IPCC climate predictions continuously fail. Not a single one has predicted actual data. You can check it out by yourself. A model that never gives a correct prediction is clearly a wrong model. Apocalypse never.': {'neg': 0.177,
#   'neu': 0.751,
#   'pos': 0.072,
#   'compound': -0.5994},
#  'Doesn&#39;t exist.😊': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'The Moon slowly moving away from Earth causing our<br>rotation to decrease = climate changes.<br><br>It&#39;s Not us tiny humans compared to the grand mysteries of our universe.': {'neg': 0.0,
#   'neu': 0.889,
#   'pos': 0.111,
#   'compound': 0.4588},
#  'The Geo Engineering sounds pretty scary. Who knows what impact that will have.': {'neg': 0.184,
#   'neu': 0.632,
#   'pos': 0.184,
#   'compound': 0.0},
#  'All of the sudden the climate started changing, it&#39;s unheard of. Its the humans fault. Lets stop the climate change and sit on the highway  until all the retarded people understand that climate change is extremely dangerous and utterly abnormal. I don&#39;t understand why people are not worried, as all the predictions and models regarding climate change where spot on ! If i want to research something over the period of say an hour, then i think the best way is to record the last millisecond of that hour, analyze that millisecond and then draw my conclusions. It gives the most accurate models, and there is more room to make a model that exactly tells the story you want to tell.': {'neg': 0.095,
#   'neu': 0.837,
#   'pos': 0.067,
#   'compound': -0.6805},
#  'Lies.': {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4215},
#  'The only way to save the planet is decreasing and controlling the human population. Especially the population in Asia is too dangerous. You can create green energy, but you cannot create other source and you cannot keep the planet clean. I think governments should consider the take control of the population.': {'neg': 0.036,
#   'neu': 0.766,
#   'pos': 0.198,
#   'compound': 0.81},
#  'That is hecka scary!!': {'neg': 0.558,
#   'neu': 0.442,
#   'pos': 0.0,
#   'compound': -0.5837},
#  'Id love to believe you, but the only thing I see changing is that people pushing the green agenda, the climate cult, are getting more rich and rich and more rich more money, more money, in their pockets that&#39;s all I see  changing': {'neg': 0.0,
#   'neu': 0.665,
#   'pos': 0.335,
#   'compound': 0.9666},
#  'During the Stone Era, trees and plants were abundant, and they could be seen everywhere.<br><br>As a result, the Earth was gradually becoming colder and colder during the Stone Era<br><br>Logging and wildfires are reducing oxygen-producing trees, causing climate change. Planting more trees can help counteract these losses and cool the Earth.<br><br>🌴🌳🌲': {'neg': 0.05,
#   'neu': 0.852,
#   'pos': 0.098,
#   'compound': 0.3744},
#  'Yes, we know that C02 is a green house gas as is methane. However, the paleoclimatologists have NOT attributed the numerous rise and fall of earth&#39;s average global temperature to C02 and methane levels. If you look at earth&#39;s historical temperature cycle over the past 570 million years you will see numerous periods of when the earth&#39;s temperature rose with C02 levels remaining LOW whereas at other times the temperature remained 3-6 degrees celcius WARMER than present times with continuously falliing C02 levels. In essence,  the historical data and facts are being manipulated by power mongers to gain more wealth by advocating global catastophe to the masses, and, making a profit from their activity while gaining more power. For example, why is Al Gore now worth approximately $300,000,000? By becoming a Climate Alarmist!!!! And goverment bureaucrats are seeing that they can maybe gain more power and wealth too by advocating Climate Alarmism.': {'neg': 0.039,
#   'neu': 0.797,
#   'pos': 0.164,
#   'compound': 0.97},
#  'More climate fraud from rich billionaires, Making more billions from this and the politicians of course they&#39;re raking in billions in kickbacks from this complete Fraud!': {'neg': 0.235,
#   'neu': 0.661,
#   'pos': 0.104,
#   'compound': -0.6778},
#  'the poor And rural family cause less carbon emissions then the rich city folks,  but the rich city folk wants to blame the farmer&#39;s': {'neg': 0.159,
#   'neu': 0.618,
#   'pos': 0.223,
#   'compound': 0.4678},
#  'Fun fact: the climate has always changed': {'neg': 0.0,
#   'neu': 0.645,
#   'pos': 0.355,
#   'compound': 0.5106},
#  'Meine Arsch!': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}}

# %%
# Putting the data in a Dataframe, letter T to invert 
pd.DataFrame(res).T
# Out:
#                                                       neg    neu    pos  \
# Sea level has been suddenly rising? Sea levels ...  0.000  0.903  0.097
# I&#39;ve been searching for a good video for my...  0.000  0.570  0.430
# Leave a mark                                        0.545  0.455  0.000
# Very informative and the best video on the topic ❤  0.000  0.656  0.344
# Let&#39;s face it: Root cause is human breeding...  0.058  0.866  0.076
# ...                                                   ...    ...    ...
# Yes, we know that C02 is a green house gas as i...  0.039  0.797  0.164
# More climate fraud from rich billionaires, Maki...  0.235  0.661  0.104
# the poor And rural family cause less carbon emi...  0.159  0.618  0.223
# Fun fact: the climate has always changed            0.000  0.645  0.355
# Meine Arsch!                                        0.000  1.000  0.000
#
#                                                     compound
# Sea level has been suddenly rising? Sea levels ...    0.4404
# I&#39;ve been searching for a good video for my...    0.8070
# Leave a mark                                         -0.0516
# Very informative and the best video on the topic ❤    0.6369
# Let&#39;s face it: Root cause is human breeding...    0.1779
# ...                                                      ...
# Yes, we know that C02 is a green house gas as i...    0.9700
# More climate fraud from rich billionaires, Maki...   -0.6778
# the poor And rural family cause less carbon emi...    0.4678
# Fun fact: the climate has always changed              0.5106
# Meine Arsch!                                          0.0000
#
# [200 rows x 4 columns]

# %%
# Changing the index
vaders_Result = pd.DataFrame(res).T
vaders_Result = vaders_Result.reset_index().rename(columns={'index':'message'})

# %%
vaders_Result.head()
# Out:
#                                              message    neg    neu    pos  \
# 0  Sea level has been suddenly rising? Sea levels...  0.000  0.903  0.097
# 1  I&#39;ve been searching for a good video for m...  0.000  0.570  0.430
# 2                                       Leave a mark  0.545  0.455  0.000
# 3  Very informative and the best video on the top...  0.000  0.656  0.344
# 4  Let&#39;s face it: Root cause is human breedin...  0.058  0.866  0.076
#
#    compound
# 0    0.4404
# 1    0.8070
# 2   -0.0516
# 3    0.6369
# 4    0.1779

# %%
# Plotting Graphic about the VADER result
sns.barplot(data = vaders_Result)
plt.xlabel('Sentiment')
plt.ylabel('Percentage')
plt.title('VADER - Level of Sentiment')
# Out:
# Text(0.5, 1.0, 'VADER - Level of Sentiment')

# %%
#clean Text
def cleanTxt(text):
    text = re.sub('@[A-Za-z0-9]+', '', text)
    # Putting all letters in lower case
    text = text.lower()
    # Excluding @
    text = re.sub('@[^\s]+', '', text)
    # Excluding acent
    text = unidecode(text)
    # Excluding html tags such as <strong></strong>
    text = re.sub('<[^<]+?>','', text)
    # Excluding numbers:
    text = ''.join(c for c in text if not c.isdigit())
    # Excluding URL's:
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))', '', text)
    # Excluding punctuation 
    text = ''.join(c for c in text if c not in punctuation)
    return text

# %%
# Applying function above to clean the text from both files
twitter['message']= twitter['message'].apply(cleanTxt)

# %%
# Cleaning dataset with the function CleanTXT
commentYoutube['text']= commentYoutube['text'].apply(cleanTxt)

# %%
commentYoutube
# Out:
#                     author          published_at            updated_at  \
# 0   Joy chardonnay Roberts  2023-10-07T23:40:01Z  2023-10-07T23:40:01Z
# 1        Salpi Vartivarian  2023-10-02T13:36:41Z  2023-10-02T13:38:53Z
# 2           Anthony Morris  2023-10-01T23:10:07Z  2023-10-01T23:10:07Z
# 3                      Rmg  2023-10-01T21:59:56Z  2023-10-01T21:59:56Z
# 4   NASA Cosmos Connection  2023-10-01T14:01:34Z  2023-10-01T14:01:34Z
# ..                     ...                   ...                   ...
# 95              Paul Green  2023-02-20T15:55:48Z  2023-02-20T15:55:48Z
# 96                Freedom.  2023-02-18T06:22:53Z  2023-02-18T06:22:53Z
# 97              MichalMaps  2023-02-17T16:28:07Z  2023-02-17T16:28:07Z
# 98              pied piper  2023-02-16T22:02:14Z  2023-02-16T22:02:14Z
# 99            montesquelie  2023-02-16T01:43:02Z  2023-02-16T02:31:57Z
#
#     like_count                                               text
# 0            0                              dont believe the hype
# 1            0  i think there is a problem around  on the time...
# 2            0  what is climate change its an anti capitalist ...
# 3            0  climate change is world pieces of s i mean eli...
# 4            0
# ..         ...                                                ...
# 95           0  fly a private jet that helps big business wars...
# 96           0  climet change caused by g gor their industrial...
# 97           0  now almost every day ireland is covered in clouds
# 98           0  climate change isnt caused by hotter temperatu...
# 99           2  if the richest are so concerned about climate ...
#
# [100 rows x 5 columns]

# %%
# function textBlob - processing NLP
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
# Applying function to get results for subjectivity and polarity for the message column.
twitter['subjectivity']=twitter['message'].apply(getSubjectivity)
twitter['polarity']=twitter['message'].apply(getPolarity)

# %%
twitter.head()
# Out:
#    sentiment                                            message  \
# 0         -1   climate change is an interesting hustle as it...
# 1          1  rt  watch beforetheflood right here as  travel...
# 2          1  fabulous leonardo dicaprios film on climate ch...
# 3          1  rt fanning just watched this amazing documenta...
# 4          2  rt  pranita biswasi a lutheran from odisha giv...
#
#               tweetid  subjectivity  polarity
# 0  792927353886371840      0.250000  0.250000
# 1  793124211518832641      0.535714  0.285714
# 2  793124402388832256      1.000000  0.650000
# 3  793124635873275904      0.450000  0.300000
# 4  793125156185137153      0.400000  0.100000

# %%
# Applying function to get results for subjectivity and polarity for the text column.
commentYoutube['subjectivity']=commentYoutube['text'].apply(getSubjectivity)
commentYoutube['polarity']=commentYoutube['text'].apply(getPolarity)

# %%
commentYoutube.head()
# Out:
#                    author          published_at            updated_at  \
# 0  Joy chardonnay Roberts  2023-10-07T23:40:01Z  2023-10-07T23:40:01Z
# 1       Salpi Vartivarian  2023-10-02T13:36:41Z  2023-10-02T13:38:53Z
# 2          Anthony Morris  2023-10-01T23:10:07Z  2023-10-01T23:10:07Z
# 3                     Rmg  2023-10-01T21:59:56Z  2023-10-01T21:59:56Z
# 4  NASA Cosmos Connection  2023-10-01T14:01:34Z  2023-10-01T14:01:34Z
#
#    like_count                                               text  \
# 0           0                              dont believe the hype
# 1           0  i think there is a problem around  on the time...
# 2           0  what is climate change its an anti capitalist ...
# 3           0  climate change is world pieces of s i mean eli...
# 4           0
#
#    subjectivity  polarity
# 0      0.000000  0.000000
# 1      0.366667  0.033333
# 2      0.300000 -0.025000
# 3      0.687500 -0.312500
# 4      0.000000  0.000000

# %%
# Using wordCloud package to see the frequency of words.
allwords = ' '.join([twts for twts in twitter['message']])
wordcloud = WordCloud(background_color = 'black',width= 500, height=500, random_state=21, max_font_size=100).generate(allwords)

# %%
# Plotting result from wordCloud for the twitter text.
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Twitter WordCloud')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Using wordCloud package to see the frequency of words for Youtube text.
allwords_1 = ' '.join([twts for twts in commentYoutube['text']])
wordcloud_1 = WordCloud(width= 500, height=500, random_state=21, max_font_size=100).generate(allwords_1)

# %%
# Plotting result from wordCloud for the twitter text.
plt.imshow(wordcloud_1, interpolation='bilinear')
plt.axis('off')
plt.title('Youtube WordCloud')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Plotting for Sentiment Analysis

# %%
# Function to find Negative, Neutral and Positive sentences.
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
# Applying function getAnalysis for Youtube file.
commentYoutube['Analysis'] = commentYoutube['polarity'].apply(getAnalysis)

# %%
# Loading Twitter data
#twitter = pd.read_csv('C:/Users/joyce/Downloads/twitter_sentiment_data.csv')

# Changing information for positive, negative and neutral on Sentiment column 
twitter['sentiment'] = twitter['sentiment'].apply(getAnalysis)

# %%
twitter
# Out:
#       sentiment                                            message  \
# 0      Negative   climate change is an interesting hustle as it...
# 1      Positive  rt  watch beforetheflood right here as  travel...
# 2      Positive  fabulous leonardo dicaprios film on climate ch...
# 3      Positive  rt fanning just watched this amazing documenta...
# 4      Positive  rt  pranita biswasi a lutheran from odisha giv...
# ...         ...                                                ...
# 43938  Positive  dear \nyeah right human mediated climate chang...
# 43939  Positive  what will your respective parties do to preven...
# 43940  Positive  rt  un poll shows climate change is the lowest...
# 43941   Neutral  rt  i still canqt believe this gif of taehyung...
# 43942  Positive    \n\nthe wealthy  fossil fuel industry know c...
#
#                   tweetid  subjectivity  polarity
# 0      792927353886371840      0.250000  0.250000
# 1      793124211518832641      0.535714  0.285714
# 2      793124402388832256      1.000000  0.650000
# 3      793124635873275904      0.450000  0.300000
# 4      793125156185137153      0.400000  0.100000
# ...                   ...           ...       ...
# 43938  791307031919550464      0.158929  0.071429
# 43939  791316857403936768      0.050000  0.000000
# 43940  791357509101621249      0.000000  0.000000
# 43941  791390042136641537      0.050000  0.000000
# 43942  791401610308038656      0.672222  0.425000
#
# [43943 rows x 5 columns]

# %%
# Plotting Twitter Sentiment Analysis
twitter.sentiment.value_counts().plot(kind='bar')
plt.title('Twitter - Sentiment Analysis ')
# Out:
# Text(0.5, 1.0, 'Twitter - Sentiment Analysis ')

# %%
commentYoutube.head()
# Out:
#                    author          published_at            updated_at  \
# 0  Joy chardonnay Roberts  2023-10-07T23:40:01Z  2023-10-07T23:40:01Z
# 1       Salpi Vartivarian  2023-10-02T13:36:41Z  2023-10-02T13:38:53Z
# 2          Anthony Morris  2023-10-01T23:10:07Z  2023-10-01T23:10:07Z
# 3                     Rmg  2023-10-01T21:59:56Z  2023-10-01T21:59:56Z
# 4  NASA Cosmos Connection  2023-10-01T14:01:34Z  2023-10-01T14:01:34Z
#
#    like_count                                               text  \
# 0           0                              dont believe the hype
# 1           0  i think there is a problem around  on the time...
# 2           0  what is climate change its an anti capitalist ...
# 3           0  climate change is world pieces of s i mean eli...
# 4           0
#
#    subjectivity  polarity  Analysis
# 0      0.000000  0.000000   Neutral
# 1      0.366667  0.033333  Positive
# 2      0.300000 -0.025000  Negative
# 3      0.687500 -0.312500  Negative
# 4      0.000000  0.000000   Neutral

# %%
# Plotting Youtube Sentiment Analysis
commentYoutube.Analysis.value_counts().plot(kind='bar') #pd.DataFrame(res).T
plt.title('Youtube - Sentiment Analysis ')
# Out:
# Text(0.5, 1.0, 'Youtube - Sentiment Analysis ')

# %%
# Creating a new dataframe for Comments Youtube to work with the colunm analysis
CY_2=pd.DataFrame(commentYoutube)

# %%
CY_2.head()
# Out:
#                    author          published_at            updated_at  \
# 0  Joy chardonnay Roberts  2023-10-07T23:40:01Z  2023-10-07T23:40:01Z
# 1       Salpi Vartivarian  2023-10-02T13:36:41Z  2023-10-02T13:38:53Z
# 2          Anthony Morris  2023-10-01T23:10:07Z  2023-10-01T23:10:07Z
# 3                     Rmg  2023-10-01T21:59:56Z  2023-10-01T21:59:56Z
# 4  NASA Cosmos Connection  2023-10-01T14:01:34Z  2023-10-01T14:01:34Z
#
#    like_count                                               text  \
# 0           0                              dont believe the hype
# 1           0  i think there is a problem around  on the time...
# 2           0  what is climate change its an anti capitalist ...
# 3           0  climate change is world pieces of s i mean eli...
# 4           0
#
#    subjectivity  polarity  Analysis
# 0      0.000000  0.000000   Neutral
# 1      0.366667  0.033333  Positive
# 2      0.300000 -0.025000  Negative
# 3      0.687500 -0.312500  Negative
# 4      0.000000  0.000000   Neutral

# %%
# Extracting the Positive text
j = 1
sortedcommentYoutube = commentYoutube.sort_values(by = ['polarity'])
for i in range(0, sortedcommentYoutube.shape[0]):
    if(sortedcommentYoutube['Analysis'][i]=='Positive'):
        print(str(j)+ ')'+ sortedcommentYoutube['text'][i])
        print()
        j = j+1
# Out:
# 1)i think there is a problem around  on the time line you have marked various historical monuments but they do not correspond to the dates you have indicated the ancient greeks werent around  years ago they thrived from  bce to  bce the start of the ancient egyptian civilization was  bce not  years ago
#
# 2)the climate has always been changing from ice ages to tropical the climate hysteria is a farce and a scam if they were serious they would look to the root cause too many people human extermination should be their logical solution why isnt it because its really about money follow the money
#
# 3)sea level has been suddenly rising sea levels have been rising at the same rate for hundreds of years its easy to find the statistics on noaas website
#
# 4)ive been searching for a good video for my students this actually helps thank you
#
# 5)very informative and the best video on the topic
#
# 6)lets face it root cause is human breeding run amok  overpopulationuntil this is addressed theres no hope of slowing down climate changeeg indias population doubled between  and  how many kids do you have
#
# 7)great propaganda
#
# 8)climate change was invented bu our corrupt government to gain more and more control what a bunch of bullshit real scientists say this is not true  climate change is about government control
#
# 9)these crush courses are great  if you subtitle them as we would be a great help for all
#
# 10)ti is the latest war on the human race and it is about  money making machine for a few people of this worldok so the human race can help reduce pollution on the planet there is technology available to day to reduce pollution on coal powered power stations and on cars trucks motorcycles and so on but the governments of the world are not interested in this technology because no one wonted to pay for it cost  dollars per unit for cars trucks  motorcyclesand son but nothing from anyone so as fare as i can see the governments of this world are full of bs this is about ajender   is alive an well as you can seepopulation control and population reduction in the world
#
# 11)think of current climate change as being global warming due to the amplification of the greenhouse effect due to an increase in greenhouse gases if you understand the physics of the greenhouse effect as being the inhibition of infrared light heat from passing freely thru the atmosphere thus resulting in a blanketing effect then youre all set to proceed to applying this knowledge and sharing it with others
#
# 12)thank you very very much
#
# 13)reaserch needed how wars regional conflicts oil depots bombing frequent war exercises affect the climate changeso peace treaties denuclearisation final border lines drawn needed to end the annoymities greed of economy selling arms need ro get overfocus on new techs on spaceships to travel at almost the speed of light to land on earth like planets
#
# 14)i woyld like more details from the video eg how much does war and the military industry contribute to global emissionshow much energy could be saved if iot internet streaming etc was halted all that green googlewindmill energy could instead be used where fossil fuel is usedto which extend does solar storms radiation etc influence the temperature on earth over timehas the temparature been rising the centuties just before the industrial revolution and how much  and whyhow much does the  pct most rich people contribute to ressource usage and thereby co contributionhow much natural co does nature release through forest fires volcanos wild life etc
#
# 15)c                                                         global warming will endgods way     the bible tells us that quotthe former of the earth and the maker of it did not create it simply for nothingquot isaiah  the bible also says quotthe earth endures foreverquotecclesiastes  the new english bible      yes god will not allow the earth to be uninhabitable rather he will intervene in human affairs and bring an end to failed human rule and those who have no regard for the earth at the same time he will preserve alive all who lead morally upright lives and sincerely want to please him says proverbs   quotthe upright are the ones that will reside in the earth and the blameless are the ones that will be left over in it as regards the wicked they will be cut off from very earth and as for the treacherous they will be torn away from itquot
#
# 16)rev  kjvand all that dwell upon the earth shall worship him whose names are not written in the book of life of the lamb slain from the foundation of the worldaaims of the papacy great controversy  ellen g white
#
# 17)stop suvs plant more trees
#
# 18)this video is good
#
# 19)free this world with war and atomic bombs otherwise whatever you do its not useful anyway ultimately this world is going to its end the day of judgment is coming very soon be prepare yourself for next life either in paradise or hell if you are not a believer of god then consider stephen hawking wording that this earth could be destroyed next one thousands years
#
# 20)good effort and much needed content
#
# 21)ok for one  great barrier reef have never been big then now and never been more  arctic and antarctic ice  since humans have been around if you want to try and shut some one up at lest have your facts strait  i am dun talking with you as you clearly just have a agenda and no knowledge of what you speak  the skys are falling the skys are falling you coward  stop trying to scare people with lies  every stupid prediction you people come up with fails and dose the opposite of what you say are you not tired of being wrong or would you just rather arson in all of canadas forests to try and prove your agenda  give it up move on to something new more real
#
# 22)a hoax of grand proportions
#
# 23)hi clickview you dont have to do a qampa video but do you think youre a good person if so do you think theres an afterlife also im not better than anybody else
#
# 24)why do we have to have natural disasterswe receive major blows from nature ultimately in order to shake us out of the state where we live according to an egoistic paradigmwith exploitation manipulation and hatred dwelling in our connectionsto a state where we positively connect as described by the words as one man with one heart ie as a single welloiled interconnected and interdependent systemin other words if we shared a harmonious and balanced connection to each other on the human level then the balance at our level would ripple throughout nature and we would experience nature harmoniously and peacefully and natural disasters as we call them would become a thing of the pastwe would be wise to pay attention to the future states that we can achieve out of such blows that the blows come to shake us out of our current dreamlike state in our egoistic attitudes to each other and wake us up into an opposite harmonious and peaceful worldin fact we live in a world that is all good and only we human beings give the world a negative form in our egoistic attitudes to each other the time is nearing when we will awaken to the need to stop relating to each other through egoistic lenseswhere we each prioritize selfbenefit at others expenseand instead relate patiently to each other with positive kind and caring attitudesif we made such a switch we would bear witness to a good life the likes of which we have never before experienced we should thus try to reach such relations as quickly as possible
#
# 25)hi creator this is great video to explanation about climate change can i use this video to do my presentation i have presentation about climate change dont worry i will mention the creator of this video many thanks to you
#
# 26)climate change is really chemtrails and haarp which is weather manipulation by your govt its bs to bring in carbon taxes basically to tax the air you breathe
#
# 27)climate change take a look at the world around you the environment is just like any human or animalit is alive when we litter on the ground use cars with  or burn down a forest and the earth feels pain and think about it we have to live here does it really make sense to damage the place we  live on if the whole world gathered together we could get it done in hours               but thats just pushing it but seriously if we want to preserve our             environment and our lives we must work as a unit if we want to get things            done then the environment would become beautiful like something out of            a fairy tale story
#
# 28)mostly bullshit
#
# 29)people tend to only show concern when major events or personal circumstances affect them as humans we often prioritize our own interests and fail to extend the same level of care and concern to others this raises the question why is it so hard to care for others perhaps its because theres no monetary reward for doing so however if we want to make the world a better place we need to start caring more though it may be challenging its important to start taking action now after all if we dont start now when will we
#
# 30)climate change climate change is a global issue and we must work together to save our world but what exactly is climate change  our planets climate has changed throughout history  alternating ice ages and warmer periods earth has been through at least   major ice ages with the last one ending   years ago so if the climate has always changed  why is climate change such a big issue today  since the start of the industrial revolution in  earths average has risen  faster than ever before this effect is known as global warming and its caused by the increase of green house immersion  from human activity  greenhouse gases occur naturally on our planet but human activities  such as the burning of fossil fuels agriculture deforestation  and the decomposition of waste in landfills have increased  the amount of green house gases dramatically  green house gases act like a blanket around earth trapping the heat from the suns rays  this is called the green house effect  thanks to this effect  earth has just the right  temperature  for life to thrive on it unlike other planets in our solar system  however if the greenhouse effect becomes too strong it starts to cause issues  the increased  temperatures we are experiencing now are causing ice in the artic and antarctica  as well as glaciers and snow around the world  to melt the water created by the melting ice pours into the oceans causing sea levels to rise this puts all islands in danger of disappearing  especially those in the pacific and caribbean ranges rising sea  levels  are also causing devastating floods in countries like china indonesiaphilippines malaysia and thailand not only are these floods a direct hazzard  to humans but can also destroy crops and farms used to feed the population another effect  of the rising temperatures is that oceans warm up and evaporate faster than normal increasing the occurrence of severe storms and heavy rainfall global warming is making weather more  extreme  bringing longer droughts and heatwaves the loss of soil moisture  and the high temperatures increase the risks of wildfire too the high temperatures on both land and in our oceans  effect  earths delicate ecosystems many animals are forced to migrate  to other areas to survive  while others are  loosing their habits and dying  so can we do anything  to stop the effects of climate change  climate change has already reached a point that humanity has never experienceed before  however  the future of our planet  is in our hands communities must make smart choices and tackle this issue with  environmentally friendly actions  some solutions to limit global warming  include  switching from burning  fossil fuels to renewable and greener energy  sources  like solar hydroelectric or wind energy  reducing the emissions  caused by  industryof transportation by investing into greener technology and limiting the deforestation of land and investing in more space efficient forms of agriculture  like vertical farming  these are all big solutions but there are also smaller things that you could easily do at home for example  recycling  composting your organic waste eating more vegetables and fruits and fewer meat and dairy products saving electricity and buying things that last longer or that can be reused people around the world are working together  to innovate engineer  and develop solutions for the issue of climate change bhutan  is the worlds most  carbonnegative  country  costa rica  has achieved  renewable energy  and now china is the world leader in wind power  climate change is a global issue and our future depends on the actions we take today
#
# 31)the problem has been well known for at least  years now and yet it remains largely unaddressed in most parts of the world the explosive population growth along with the increased demand for energy consumption has not been the least affected by western world campaigns and switching to electric cars is not going to save earth or the human species there are still entire continents where the word pollution remains more or less an unknown so unless the whole world lifts together we reman doomed
#
# 32)very helpful  currently studying for my test im a marine biology student
#
# 33)its crucial that we take action to mitigate the effects of climate change whether its through reducing our carbon emissions promoting renewable energy or advocating for policy changes
#
# 34)this is the best explanation on this video thank you very much
#
# 35)haha all a scam when i was in school the world was supposed to be gone by now the earth is always changing how do you think the ice age left wake up people abs stop fearing everything  they push your way line a little kid wake up  california pushing electric cars where the batteries cause more harm and that cant even handle a warm day without blackouts scam
#
# 36)the earth has had degc rises in  years in the past that one fact alone decimates the human caused global warming hoax people like john kerry are making a fortune on this scam now all the elites are taking your tax dollars telling you it will save the planet look up catastrophism its a thing this planet and all other planets in our solar system go through limited deforestation is definitely good stop dumping garbage is another good idea china is the world leader in coal plants this video is pure propaganda and nothing more wtfu people read research
#
# 37)omg thank you the best person person in the world really you explained everything straight forward and without any unwanted stuff thanks to you i understood how this enormous circle works
#
# 38)had snow for  straight months here in so utah when the hell is this climate change going to show up
#
# 39)what a steaming load were supposed to care about quotclimate changequot when the rich greedy people fly in their private jets to talk about how the common person is causing the temperature to go up and down its hilariously sad really
#
# 40)subsaharan development is literally killing uswhere in the developed world sub saharans terroism is driving urban sprawloddly climate change has been primarily caused by the fossil fuels used to transform once topsoil carbon sink into more starving methane emitters in subsaharan africa oh suredevelopment seems to be the only way to figure out how many of them actually live in africabut is that really worth it
#
# 41)what is climate change a big hoax im  been hearing this lie since i was in grade school im  been hearing this lie since i was in grade school i live in ohio its still hot in the summer  cold in the winter rains a lot in the spring and is just right for football in the fall go bucks
#
# 42)im amazed at how calm he is as he is narrating this
#
# 43)fly a private jet that helps big business warship money and power  electricity benefits ai robots technology will we  are we being replaced see eye see
#
# 44)if the richest are so concerned about climate change that they are contributing the most why no single rich person suggests to limit everyone plane journeys say to k kilometers a year they instead want majority to eat bugs and warms instead to save the planet from their pollution just liers

# %%
# Extracting the negative text
j = 1
sortedcommentYoutube = commentYoutube.sort_values(by = ['polarity'])
for i in range(0, sortedcommentYoutube.shape[0]):
    if(sortedcommentYoutube['Analysis'][i]=='Negative'):
        print(str(j)+ ')'+ sortedcommentYoutube['text'][i])
        print()
        j = j+1
# Out:
# 1)what is climate change its an anti capitalist anti industrialization anti impact anti western authoritarian leftist death cult
#
# 2)climate change is world pieces of s i mean elites playing with haarp
#
# 3)its bsthats what climate change isi will break it down for yousummer winter spring and fall
#
# 4)humans are destroying the natural environment
#
# 5)i like its just a little to long
#
# 6)climate change is bulshit propaganda for excuse to raise taxes by socialist left wing governments
#
# 7)its sad that all these world leaders and the united nations havent really done anything to stop climate the worst part is that they knew about climate change for more than  years and nothing is done they always talk about how bad climate change is and dont really do anything
#
# 8)if producing releasingunlocking co is so bad for the world why dont we have a socially woke  campaign to ostracize and persecute people who buy and consume coca cola pepsi etc   surely the mass production and distribution of co in this way is a crime against the planet that climate change believers and the un should move to shut down
#
# 9)people that believe in climate change are just as dumb as the people believe that the earth is flat
#
# 10)so full of crap stop pushing this lie
#
# 11)climate change has since earliest written history of urbanisation of man kinds as phenomenon is a present danger and existential threat to human urban habitation and intrinsic globalist military industrial economy not a present danger and existential threat to the human species per say
#
# 12)chemtrails is cloud seeding now well documented weather manipulation using harmful dry ice hygroscopic flares and silver iodine the csiro and militaries toxic secrets raise red flags over everything the public has fully known about this topic now environmental quotcontrolquot of people has crossed over this era has blurred the lines of truth imo
#
# 13)thank you clickviewyour video on climate change is very informative and you have provided the solutions to the problem i think every country knows about the solution but if these solutions are followed then dont you think the massive population will be left with no alternative please do not take me in a negative sense as i am mentioning on my personal experience my cousin is a butcher and he is into this profession since childhood now all of a sudden he will be asked to leave his profession then i thing everyone associated with his output will be in a state of doldrums he is supplying flesh to different organization and the supply in not in kgs but tonnes it is the duty of every individuals to take the ownership then situation will come to a normal once i had a very rough argument with a chicken seller few years ago from then onwards i left consuming chicken even during any occasion i would go for some other food item but not chicken i think i did my part if everyone takes the ownership then there will be a change sooner or later finally your video is an eyeopener and it should be brought to the notice of the legislature who can make some laws and the executive will have some binding effect i believe it is just the game of demand and supplybest wisheskhwaja ram
#
# 14)climate change isnt caused by hotter temperatures but by increased oceanic swelling  such oceanic swelling is what drives extreme weather patterns  ships wakes transport air pressure changes wind power all contribute to increased waves and therefore extreme weather patterns

# %%
# Create a text widget for displaying results
result_text = widgets.Output()
display(result_text)

# Define a function to update the dashboard with results
def update_dashboard(sentiment):
    filtered_data = twitter[twitter['sentiment'] == sentiment]
    with result_text:
        clear_output()
        display(filtered_data)

# Create widgets for sentiment selection
sentiment_selector = widgets.Dropdown(
    options=['Positive', 'Negative', 'Neutral'],
    value='Positive',
    description='Sentiment:',
    disabled=False,
)

# Define a function to update the dashboard when the sentiment is changed
def on_sentiment_change(change):
    update_dashboard(change.new)

sentiment_selector.observe(on_sentiment_change, names='value')

# Display the widgets and initial dashboard
display(sentiment_selector)
update_dashboard(sentiment_selector.value)
# Out:
# Output()
# Dropdown(description='Sentiment:', options=('Positive', 'Negative', 'Neutral'), value='Positive')

# %%
# Create a text widget for displaying results
result_text = widgets.Output()
display(result_text)

# Define a function to update the dashboard with results
def update_dashboard(Analysis):
    filtered_data = CY_2[CY_2['Analysis'] == Analysis]
    with result_text:
        clear_output()
        display(filtered_data)

# Create widgets for sentiment selection
sentiment_selector = widgets.Dropdown(
    options=['Positive', 'Negative', 'Neutral'],
    value='Positive',
    description='Sentiment:',
    disabled=False,
)

# Define a function to update the dashboard when the sentiment is changed
def on_sentiment_change(change):
    update_dashboard(change.new)

sentiment_selector.observe(on_sentiment_change, names='value')

# Display the widgets and initial dashboard
display(sentiment_selector)
update_dashboard(sentiment_selector.value)
# Out:
# Output()
# Dropdown(description='Sentiment:', options=('Positive', 'Negative', 'Neutral'), value='Positive')

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(twitter['message'], twitter['sentiment'], test_size=0.2, random_state=42)

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  # The number of features
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# SVM Model
svm_classifier = SVC(kernel='linear', C=1)
svm_classifier.fit(X_train_tfidf, y_train)
svm_predictions = svm_classifier.predict(X_test_tfidf)
# Calculate accuracy
svm_accuracy = accuracy_score(y_test, svm_predictions)

# %%
# Naive Bayes Model
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_tfidf, y_train)
nb_predictions = nb_classifier.predict(X_test_tfidf)
# Calculate accuracy
nb_accuracy = accuracy_score(y_test, nb_predictions)

# %%
print(f'SVM Accuracy: {svm_accuracy:.2f}')
print(f'Naive Bayes Accuracy: {nb_accuracy:.2f}')
# Out:
# SVM Accuracy: 0.81
# Naive Bayes Accuracy: 0.77

# %%
# Confusion Matrix for SVM
svm_cm = confusion_matrix(y_test, svm_predictions)
print("Confusion Matrix for SVM:")
print(svm_cm)

# Confusion Matrix for Naive Bayes
nb_cm = confusion_matrix(y_test, nb_predictions)
print("\nConfusion Matrix for Naive Bayes:")
print(nb_cm)
# Out:
# Confusion Matrix for SVM:
# [[ 315  100  369]
#  [  44  584  954]
#  [  55  184 6184]]
#
# Confusion Matrix for Naive Bayes:
# [[ 118   49  617]
#  [   6  285 1291]
#  [  15   62 6346]]

# %%
# Plot Confusion Matrix for SVM
plt.figure(figsize=(8, 6))
sns.heatmap(svm_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('SVM Confusion Matrix')
plt.show()

# %%
# Plot Confusion Matrix for Naive Bayes
plt.figure(figsize=(8, 6))
sns.heatmap(nb_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Naive Bayes Confusion Matrix')
plt.show()
